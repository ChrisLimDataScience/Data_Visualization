# %% [markdown]
# There are many Python packages for Data Visualization
#
# 1. Matplotlib
# 2. Plotly
# 3. Bokeh
# 4. ggplot
# 5. Seaborn

# %% [markdown]
# Pyplot - sub-library of matplotlib
#
# Documentation - https://matplotlib.org/
#
# Note: All the datasets used in today's notebook are available in the google drive link - https://drive.google.com/drive/folders/1NxCh4X7u7wVo5aHojxjLNs9wC7B7zJhb?usp=sharing

# %%
# Usage - 

# import matplotlib
# import matplotlib.pyplot

# %%
# alternate usage

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Line Plot

# %%
year = [2016, 2017, 2018, 2019, 2020]
enrollment = [70, 150, 130, 180, 220]
plt.plot(year, enrollment, marker='o')
plt.show()

# %% [markdown]
# Line formatting, labels, legends

# %%
plt.plot(year, enrollment,'g*--')

# %%
# Change the marker

plt.plot(year, enrollment, marker ='o')
plt.show()

# https://matplotlib.org/2.0.2/api/markers_api.html

# Change the line style

plt.plot(year, 	enrollment, marker ='o', linestyle='--')
plt.show()

# Set the color

plt.plot(year, enrollment, 	marker ='o', linestyle='--', color = 'r')
plt.show()

# https://matplotlib.org/2.0.2/api/colors_api.html

# Simpler usage

plt.plot(year, enrollment, 'ro--')
plt.show()

# To see the changes separately, you have to use plt.show() after every plt.plot(). Otherwise, the changes get applied on the same plot.

# %%
# Add labels, title and controlling axes ranges
plt.plot(year, enrollment, 'ro--')

# Add labels
plt.xlabel('Year')
plt.ylabel('Enrollment')

# Add title
plt.title('Class Enrollment')

# Control axes range
# syntax - plt.axis([xmin, xmax, ymin, ymax])
plt.axis([2014, 2022, 0, 300])

plt.show()

# %%
year = [2016, 2017, 2018, 2019, 2020]
ITP449 = [70, 150, 130, 180, 220]
ITP115 = [180, 250, 390, 540, 720]

plt.plot(year, ITP449, marker ='o', linestyle='--', color = 'r', label='ITP449')
plt.plot(year, ITP115, marker ='s', linestyle='-.', color = 'b', label='ITP115')

# Add labels
plt.xlabel('Year')
plt.ylabel('Enrollment')

# Add title
plt.title('ITP Enrollment')

# Control axes range
plt.axis([2014, 2022, 0, 800])

# legend and grid
plt.legend()
plt.grid(True, color='y', linestyle=':')

plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
year = [2016, 2017, 2018, 2019, 2020]
ITP449 = [70, 150, 130, 180, 220]
ITP115 = [180, 250, 390, 540, 720]

plt.scatter(year, ITP449, marker ='o', color = 'r', label='ITP449')
plt.scatter(year, ITP115, marker ='s', color = 'b', label='ITP115')

plt.xlabel('Year')
plt.ylabel('Enrollment')

plt.title('ITP Enrollment')

plt.axis([2014, 2022, 0, 800])

# legend and grid
plt.legend()

plt.show()

# %%
# plot styles

print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ### Bar Plot

# %%
year = [2016, 2017, 2018, 2019, 2020]

ITP449 = [70, 150, 130, 180, 220]
ITP115 = [180, 250, 390, 540, 720]

plt.bar(year, ITP115, label='ITP115', color='b')
plt.bar(year, ITP449, label='ITP449', color='r')

plt.xlabel('Year')
plt.ylabel('Enrollment')

plt.title('ITP Enrollment')

plt.axis([2014, 2022, 0, 800])

# legend and grid
plt.legend()

plt.show()

# %%
# use style
plt.style.use('fivethirtyeight')

year = [2016, 2017, 2018, 2019, 2020]

ITP449 = [70, 150, 130, 180, 220]
ITP115 = [180, 250, 390, 540, 720]

plt.bar(year, ITP115, label='ITP115', color='b')
plt.bar(year, ITP449, label='ITP449', color='r')

plt.plot()

plt.xlabel('Year')
plt.ylabel('Enrollment')

plt.title('ITP Enrollment')

plt.axis([2014, 2022, 0, 800])

# legend and grid
plt.legend()

plt.show()

# %%
plt.style.use('ggplot')
rainfall = [15, 19, 18, 13, 11, 7, 8, 7, 10, 12, 14, 15]
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.bar(months, rainfall)
plt.xticks(rotation=45)
plt.xlabel('Month')
plt.ylabel('Rainfall (cm)')
plt.title('Rainfall')
plt.savefig('rainfall.png', bbox_inches='tight') # save figure
plt.show()

# %% [markdown]
# ### Pie Charts

# %%
plt.style.use('ggplot')
browsers = ['Chrome', 'Firefox', 'Internet Explorer', 'Safari', 'Others']
marketShare = [61.64, 18.98, 11.02, 4.23, 4.13]
plt.pie(marketShare, labels=browsers, autopct='%.1f%%', startangle=45)
plt.title('Browser Market Share')
plt.axis('equal')
plt.show()

# %%
plt.style.use('seaborn')
labels = ['Chrome', 'Firefox', 'Internet Explorer', 'Safari', 'Others']
marketShare = [61.64, 18.98, 11.02, 4.23, 4.13]
plt.pie(marketShare, labels=labels, autopct='%.1f%%', startangle=45,
        explode=[0, 0, 0, 0.5, 0.5]) # split and display portion of pie chart
plt.title('Browser Market Share')
plt.axis('equal')
plt.legend(labels, loc='lower left') # legend
plt.show()

# %%
# plot of x^3
plt.style.use('ggplot')
plt.plot([0, 1, 2, 3, 4], [0, 1, 8, 27, 64])
plt.axis([0, 4, 0, 64])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X^3')
plt.show()

# %%
plt.style.use('ggplot')
x = np.arange(0, 4.1, 0.1)
print(len(x))
plt.plot(x, x**3)
plt.axis([0, 4, 0, 64])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X^3')
plt.show()
# Out:
# 41

# %%
# plot x^2, x^3 and x^4
plt.style.use('ggplot')
x = np.arange(-4, 4.1, 0.1)
#plt.plot(x, x**2, x, x**3, x, x**4)
plt.plot(x,x**2)
plt.plot(x,x**3)
plt.plot(x,x**4)
plt.axis([-4, 4, -100, 100])
plt.xlabel('X')
plt.ylabel('Y')
plt.legend(['x^2', 'x^3', 'x^4'])
plt.show()

# %% [markdown]
# ### Figures
#
# When you create a plot, a figure object is automatically created.
# You can create multiple figures and refer to them by their number.

# %%
plt.style.use('ggplot')

plt.figure(1)
x = np.arange(-4, 4.1, 0.1)
plt.plot(x, x**2)
plt.axis([-4, 4, -70, 70])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('x^2')

plt.figure(2)
x = np.arange(-4, 4.1, 0.1)
plt.plot(x, x**4)
plt.axis([-4, 4, -70, 70])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('x^4')

plt.show()

# %% [markdown]
# ### Subplots - A set of plots within a figure.
#
# Each subplot focuses on a slice of the overall data.
# Each subplot has an index so that each plot can be addressed -
#
# plt.subplot(number of x plots, number of y plots, chart #)
#
# example -
#
# plt.subplot(2, 2, 1)
# plt.subplot(2, 2, 2)
# plt.subplot(2, 2, 3)
# plt.subplot(2, 2, 4)

# %%
plt.style.use('ggplot')

x = np.arange(0, 4, 0.1)

plt.subplot(1, 3, 1) # 1 row, 2 cols, chart 1
plt.plot(x, x**(1/2), 'y^', x, x**(1/3), 'bo', x, x**(1/4), 'r--')
plt.axis([0, 4, 0, 3])
plt.legend(['x^(1/2)', 'x^(1/3)', 'x^(1/4)'])

plt.subplot(1, 3, 2) # 1 row, 2 cols, chart 2
plt.plot(x, x**2, 'y^', x, x**3, 'bo', x, x**4, 'r--')
plt.axis([0, 4, 0, 70])
plt.legend(['x^2', 'x^3', 'x^4'])

plt.subplot(1, 3, 3)

plt.show()

# %% [markdown]
# You can create a blank figure
# And then add subplots to it

# %%
# clear runtime to get rid of grids
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

plt.show()

# %%
myFig = plt.figure()

ax1 = myFig.add_subplot(2, 2, 1)
ax2 = myFig.add_subplot(2, 2, 2)
ax3 = myFig.add_subplot(2, 2, 3)

ax1.hist(np.random.randn(1000), bins=50, color='m')
ax2.scatter(np.arange(30), np.arange(30) + 2 * np.random.randn(30), color='b')
ax3.plot(np.random.randn(50).cumsum(), 'g--') # cumulation sum of standard normal distribution of 50 numbers (mean = 0, variance = 1)
plt.show()

# %%
# Generates an array of subplots 2 x 2
# myFig refers to figure
# myAxes refers to axes
# myAxes[i, j] refers to a subplot

myFig, myAxes = plt.subplots(3, 3)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# histogram

myFig, myAxes = plt.subplots(2, 2, sharex=False, sharey=True) # share x and y axis
for i in range(2):
    for j in range(2):
        myAxes[i, j].hist(np.random.randn(1000), bins=50, color='m', alpha=0.5)
plt.show()

# %%
myFig, myAxes = plt.subplots(1, 4, sharey=True, squeeze=False) # Squeeze = False is used to allow proper indexing of axes

myData = np.random.randn(1000)
myAxes[0, 0].hist(myData, bins=10, color='r')
myAxes[0, 1].hist(myData, bins=20, color='b')
myAxes[0, 2].hist(myData, bins=50, color='k')
myAxes[0, 3].hist(myData, bins=100, color='g')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
ax.plot(np.random.randn(1000).cumsum())
ax2.plot(np.random.randn(1000).cumsum())
plt.show()

# %%
# setting ticks and labels and rotating tick labels

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.plot(np.random.randn(1000).cumsum())
ticks = ax.set_xticks([0, 250, 500, 750, 1000]) # xticks
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='medium') # xtick labels
ax.set_title('Plot using subplots')
ax.set_xlabel('Stages')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.plot(np.random.randn(1000).cumsum(), 'k', label='one')
ax.plot(np.random.randn(1000).cumsum(), 'm--', label='two')
ax.plot(np.random.randn(1000).cumsum(), 'b.', label='three')
ax.legend(loc='best') # legend position
plt.show()

# %%
plt.style.use('seaborn')
puzzleCompletionTime = [139, 53, 96, 166, 182, 197, 211, 427, 215, 232, 297, 180, 144, 268]
plt.hist(puzzleCompletionTime, bins=5, color='#2185AC', rwidth=0.8) # color can also be specified in this format
plt.xlabel('Completion Time (sec)')
plt.ylabel('# of Contestants')
plt.title('Puzzle Completion Time')
plt.show()

# %% [markdown]
# Upload the dataset grade5ScienceFairProject.csv using any of the methods mentioned in the previous lecture.

# %%
plt.style.use('seaborn')
puzzleCompletionTime = pd.read_csv('grade5ScienceFairProject.csv')
puzzleCompletionTime = puzzleCompletionTime.head(500)
print(puzzleCompletionTime)
plt.hist(puzzleCompletionTime['Seconds'], bins=5, color='#2185AC', rwidth=0.8)
plt.xlabel('Completion Time (sec)')
plt.ylabel('# of Contestants')
plt.title('Puzzle Completion Time')
plt.show()
# Out:
#     Seconds Music
# 0        39  Fast
# 1        53  Fast
# 2        56  Fast
# 3       166  Fast
# 4       182  Fast
# 5       197  Fast
# 6       427  Fast
# 7        32  None
# 8        47  None
# 9        80  None
# 10      114  None
# 11      197  None
# 12       78  Slow
# 13      116  Slow
# 14      123  Slow
# 15      155  Slow
# 16      263  Slow

# %%
import seaborn as sb

# %%
# load csv data

puzzleCompletionTime = pd.read_csv('grade5ScienceFairProject.csv')

# %%
# swarm plot

sb.set_style('whitegrid')
sb.swarmplot(y='Seconds', data=puzzleCompletionTime)
plt.show()

# %%
sb.set_style('whitegrid')
sb.swarmplot(x='Music', y='Seconds', data=puzzleCompletionTime, size=10)
plt.show()

# %%
# superimpose a box plot on a swarm plot

sb.set_style('whitegrid')
sb.swarmplot(x='Music', y='Seconds', data=puzzleCompletionTime, size=10)
sb.boxplot(x='Music', y='Seconds', data=puzzleCompletionTime)
plt.show()

# %% [markdown]
# Upload the dataset salaries.csv using any of the methods mentioned in the previous lecture.

# %%
sb.set_style('whitegrid')
salaryData = pd.read_csv('salaries.csv')
sb.swarmplot(x='gender', y='salary', data=salaryData)
ax = plt.gca() # get current axes
ax.set_title('Salary Distribution')
plt.show()

# %% [markdown]
# Upload the dataset drivers.csv using any of the methods mentioned in the previous lecture.

# %%
# catplot

driverData = pd.read_csv('drivers.csv')
g = sb.catplot(x='gender', y='license', col='group',
               data=driverData, kind='bar', ci=None)
g.set_axis_labels('Gender', 'Proportion with Driving license')
g.set_xticklabels(['Men', 'Women'])
g.set_titles('{col_var} {col_name}')
plt.show()

# %% [markdown]
# Upload the dataset titanic.csv using any of the methods mentioned in the previous lecture.

# %%
titanic = sb.load_dataset('titanic')
g = sb.catplot(x='who', y='survived', col='class',
               data=titanic, kind='bar', ci=None, aspect=0.5)
g.set_axis_labels('', 'Survival Rate')
g.set_xticklabels(['Men', 'Women', 'Children'])
g.set_titles('{col_name} {col_var}')
plt.show()

# %% [markdown]
# ### Exercise
#
# Display these blank subplots using subplot functions
#
# ![image.png](data:image/png;base64,...)

# %%
# Type solution here
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.gridspec import GridSpec
fig = plt.figure()
gs = GridSpec(2, 3, figure=fig)
ax1 = fig.add_subplot(gs[0, 0:1])
ax2 = fig.add_subplot(gs[0, 1:2])
ax3 = fig.add_subplot(gs[0, 2:3])
# identical to ax1 = plt.subplot(gs.new_subplotspec((0, 0), colspan=3))
ax4 = fig.add_subplot(gs[1, 0:1])
ax5 = fig.add_subplot(gs[1:, 1:2])
ax6 = fig.add_subplot(gs[1, 2])
# Hide grid lines
ax1.grid(False)

# Hide axes ticks
ax1.set_xticks([])
ax1.set_yticks([])
ax2.set_xticks([])
ax2.set_yticks([])
ax3.set_xticks([])
ax3.set_yticks([])
ax4.set_xticks([])
ax4.set_yticks([])
ax5.set_xticks([])
ax5.set_yticks([])
ax6.set_xticks([])
ax6.set_yticks([])


#ax = fig.add_subplot(2, 3, 1)
#ax2 = fig.add_subplot(2, 3, 2)
#ax3 = fig.add_subplot(2, 3, 3)
#ax4 = fig.add_subplot(2, 3, 4)
#ax5 = fig.add_subplot(2, 3, 5)
#ax6 = fig.add_subplot(2, 3, 6)
# Out:
# []

# %% [markdown]
# ### Exercise
#
# Display the below graph.
#
# ![image.png](data:image/png;base64,...)

# %%
# Type solution here
# Hint: check the parameters c, s and alpha of scatter plot. 
np.random.seed(1000999999)


N = 30
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = 100  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ### Exercise
#
# Use numpy to create 200 random integers between 1 and 200. Store them in X. Similarly, create 200 more random integers between 1 and 200. Then display a scatter plot of X vs Y.
# Format the plot as shown below.
#
# ![image.png](data:image/png;base64,...)

# %%
# Type solution here
import matplotlib.pyplot as plt
import numpy as np
rng = np.random.RandomState(0)


# Fixing random state for reproducibility
np.random.seed(19680801)


# unit area ellipse
rx, ry = 3., 1.
area = rx * ry * np.pi

x = (rng.rand(100)*200)
y = (rng.rand(100)*200)
s=1
c= 'r'

# Add labels
plt.xlabel('Random Integer')
plt.ylabel('Random Integer')

# Add title
plt.title('Scatter of Random Integers')

# Control axes range
# syntax - plt.axis([xmin, xmax, ymin, ymax])
#plt.axis([0, 200, 0, 200])
plt.scatter(x, y,s,c)

plt.show()

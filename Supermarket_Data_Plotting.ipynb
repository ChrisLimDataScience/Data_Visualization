# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import os
data = pd.read_csv("50_SupermarketBranches.csv")
print(data.describe()) #include=np.object
ny = data[data['State']=="New York"]
ca = data[data['State']=="California"]
fl = data[data['State']=="Florida"]
fig, axes = plt.subplots(3, 1, sharey=True, figsize=(10,15))
fig.suptitle('Spending vs Profit', fontsize=20)
axes[0].set_title("Advertisement Spending vs Profit")
axes[1].set_title("Promotion Spending vs. Profit")
axes[2].set_title("Administration Spending vs. Profit")
a = sns.lineplot(ax=axes[0], y=data['Profit'], x=data['Advertisement Spend'], hue=data['State'], style=data['State'])
b = sns.lineplot(ax=axes[1], y=data['Profit'], x=data['Promotion Spend'], hue=data['State'], style=data['State'])
c = sns.lineplot(ax=axes[2], y=data['Profit'], x=data['Administration Spend'], hue=data['State'], style=data['State'])
axes[0].set(ylabel='Profit in USD', xlabel='Spending in USD')
a.set(xlim=(0,170000),ylim=(0,200000))
b.set(xlim=(0,190000),ylim=(0,200000))
c.set(xlim=(0,480000),ylim=(0,200000))
axes[1].set(ylabel='Profit in USD', xlabel='Spending in USD')
axes[2].set(ylabel='Profit in USD', xlabel='Spending in USD')
fig. tight_layout(pad=2.0)
# Out:
#        Advertisement Spend  Promotion Spend  Administration Spend  \
# count            50.000000        50.000000             50.000000
# mean          73721.615600    121344.639600         211025.097800
# std           45902.256482     28017.802755         122290.310726
# min               0.000000     51283.140000              0.000000
# 25%           39936.370000    103730.875000         129300.132500
# 50%           73051.080000    122699.795000         212716.240000
# 75%          101602.800000    144842.180000         299469.085000
# max          165349.200000    182645.560000         471784.100000
#
#               Profit
# count      50.000000
# mean   112012.639200
# std     40306.180338
# min     14681.400000
# 25%     90138.902500
# 50%    107978.190000
# 75%    139765.977500
# max    192261.830000

# %%
# From the Market Basket Optimization, find the top 5 food orders and create a histogram that
# labels and color codes up to 20 different items.
import itertools
from collections import Counter
data2 = pd.read_csv("Market_Basket_Optimisation.csv")
output = set(data2.iloc[:,0:1].dropna()) 
for i in range(1,20):
    list2 =data2.iloc[:,i].dropna()
    output = set(output) 
    unique_list2 = set(list2) 
    # Difference in two sets 
    diff_element = unique_list2 - unique_list1 
    output = list(output) + list(diff_element)
#print(output)
data = dict()
for i in output:
    data[i]=0
for j in range(0,20):
    for i in range(0,7500):
        x = data2.iloc[i,j]
        if (pd.isna(x)):
            continue
        else:
            data[x] = data[x]+1
df = pd.DataFrame(data.items(), columns=['name','number'])
df = df.sort_values(by=['number'], ascending=False)
print(df.head())
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.histplot(data=df[:20], x=df[:20].index, y=df[:20]['number'],hue=df[:20]['name'])
# Out:
#               name  number
# 20   mineral water    1787
# 70            eggs    1348
# 36       spaghetti    1306
# 82    french fries    1282
# 118      chocolate    1230
# <AxesSubplot:ylabel='number'>

# %%
# For the Supermarket_CustomerMembers.csv, create a scatter plot that plots Age vs Income and
# is color coated by Genre (Male/Female)
df = pd.read_csv("Supermarket_CustomerMembers.csv")
print(df. columns)
fig = plt.figure(1)
fig.suptitle('Age vs Income', fontsize=20)
sns.scatterplot(y=df['Annual Income (k$)'], x=df['Age'], hue=df['Genre'], style=df['Genre'])
axes.set(ylabel='Annual Income in k $', xlabel='Age in years')
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')
# [Text(3.200000000000017, 0.5, 'Annual Income in k $'),
#  Text(0.5, 3.200000000000017, 'Age in years')]
